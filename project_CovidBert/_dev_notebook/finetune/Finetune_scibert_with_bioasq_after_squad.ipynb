# %%
import argparse
import glob
import logging
import os
import random
import timeit

#this reloads the module ( required when we updated the my_run_squad  module offline)
# %load_ext autoreload
# %autoreload 2

import torch
import importlib #import reload
import torch.nn as nn
from transformers import *
from my_run_squad import main as my_main # import main as my_main

#importlib.reload(my_run_squad)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#tokenizer = AutoTokenizer.from_pretrained("output_finetuned_model/squad")

# %%
# load model trained on squad
#model = AutoModelForQuestionAnswering.from_pretrained("output_finetuned_model/squad")

# %%
#model.train()
torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()
model_path = "output_finetuned_model/squad"
base_path = os.path.abspath('')
grand_parent_path =os.path.abspath('..\..')
#print(grand_parent_path)

# fine tune with squad v2
out_dir = os.path.join(base_path,"output_finetuned_model", "bioasq")
train_dir = os.path.join(base_path,"bioasq_data\\train_combined", "trainset_combined_squad_format.json")
#eval_dir = os.path.join(base_path,"bioasq_data\\test_combined", "BioASQ-task8bPhaseB-testset1_squad_format.json")
eval_dir = os.path.join(base_path,"bioasq_data\\test_combined", "BioASQ-task8bPhaseB-testset_combined_squad_format.json")


#print(out_dir)
#print(train_dir)
#print(eval_dir)

my_main(model_path,out_dir,train_dir,eval_dir)
# Out:
# {'model_type': 'bert', 'model_name_or_path': 'output_finetuned_model/squad', 'output_dir': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\bioasq', 'data_dir': None, 'train_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\train_combined\\trainset_combined_squad_format.json', 'predict_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\test_combined\\BioASQ-task8bPhaseB-testset_combined_squad_format.json', 'config_name': '', 'tokenizer_name': '', 'cache_dir': '', 'version_2_with_negative': True, 'null_score_diff_threshold': 0.0, 'max_seq_length': 384, 'doc_stride': 128, 'max_query_length': 64, 'do_train': True, 'do_eval': True, 'evaluate_during_training': False, 'do_lower_case': True, 'per_gpu_train_batch_size': 8, 'per_gpu_eval_batch_size': 64, 'learning_rate': 3e-05, 'gradient_accumulation_steps': 1, 'weight_decay': 0.0, 'adam_epsilo
# ...

# %%
# bioasq_test set results on test set1

{'exact': 36.0,
 'f1': 63.49474782894428,
 'total': 375,
 'HasAns_exact': 36.0,
 'HasAns_f1': 63.49474782894428,
 'HasAns_total': 375,
 'best_exact': 36.0,
 'best_exact_thresh': 0.0,
 'best_f1': 63.49474782894428,
 'best_f1_thresh': 0.0}
# Out:
# {'exact': 36.0,
#  'f1': 63.49474782894428,
#  'total': 375,
#  'HasAns_exact': 36.0,
#  'HasAns_f1': 63.49474782894428,
#  'HasAns_total': 375,
#  'best_exact': 36.0,
#  'best_exact_thresh': 0.0,
#  'best_f1': 63.49474782894428,
#  'best_f1_thresh': 0.0}

# %%
# full fine tune logs 


{'model_type': 'bert', 'model_name_or_path': 'output_finetuned_model/squad', 'output_dir': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\bioasq', 'data_dir': None, 'train_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\train_combined\\trainset_combined_squad_format.json', 'predict_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\test_combined\\BioASQ-task8bPhaseB-testset_combined_squad_format.json', 'config_name': '', 'tokenizer_name': '', 'cache_dir': '', 'version_2_with_negative': True, 'null_score_diff_threshold': 0.0, 'max_seq_length': 384, 'doc_stride': 128, 'max_query_length': 64, 'do_train': True, 'do_eval': True, 'evaluate_during_training': False, 'do_lower_case': True, 'per_gpu_train_batch_size': 8, 'per_gpu_eval_batch_size': 64, 'learning_rate': 3e-05, 'gradient_accumulation_steps': 1, 'weight_decay': 0.0, 'adam_epsilon': 1e-08, 'max_grad_norm': 1.0, 'num_train_epochs': 3.0, 'max_steps': -1, 'warmup_steps': 550, 'n_best_size': 20, 'max_answer_length': 128, 'verbose_logging': False, 'lang_id': 0, 'logging_steps': 50, 'save_steps': 2000, 'eval_all_checkpoints': False, 'no_cuda': False, 'overwrite_output_dir': False, 'overwrite_cache': False, 'seed': 42, 'local_rank': -1, 'fp16': False, 'fp16_opt_level': None, 'server_ip': '', 'server_port': '', 'threads': 2}
05/06/2020 12:57:36 - WARNING - my_run_squad -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
05/06/2020 12:57:36 - INFO - transformers.configuration_utils -   loading configuration file output_finetuned_model/squad\config.json
05/06/2020 12:57:36 - INFO - transformers.configuration_utils -   Model config BertConfig {
  "_num_labels": 2,
  "architectures": [
    "BertForQuestionAnswering"
  ],
  "attention_probs_dropout_prob": 0.1,
  "bad_words_ids": null,
  "bos_token_id": null,
  "decoder_start_token_id": null,
  "do_sample": false,
  "early_stopping": false,
  "eos_token_id": null,
  "finetuning_task": null,
  "hidden_act": "gelu",
  "hidden_dropout_prob": 0.1,
  "hidden_size": 768,
  "id2label": {
    "0": "LABEL_0",
    "1": "LABEL_1"
  },
  "initializer_range": 0.02,
  "intermediate_size": 3072,
  "is_decoder": false,
  "is_encoder_decoder": false,
  "label2id": {
    "LABEL_0": 0,
    "LABEL_1": 1
  },
  "layer_norm_eps": 1e-12,
  "length_penalty": 1.0,
  "max_length": 20,
  "max_position_embeddings": 512,
  "min_length": 0,
  "model_type": "bert",
  "no_repeat_ngram_size": 0,
  "num_attention_heads": 12,
  "num_beams": 1,
  "num_hidden_layers": 12,
  "num_return_sequences": 1,
  "output_attentions": false,
  "output_hidden_states": false,
  "output_past": true,
  "pad_token_id": 0,
  "prefix": null,
  "pruned_heads": {},
  "repetition_penalty": 1.0,
  "task_specific_params": null,
  "temperature": 1.0,
  "top_k": 50,
  "top_p": 1.0,
  "torchscript": false,
  "type_vocab_size": 2,
  "use_bfloat16": false,
  "vocab_size": 31090
}

05/06/2020 12:57:36 - INFO - transformers.configuration_utils -   loading configuration file output_finetuned_model/squad\config.json
05/06/2020 12:57:36 - INFO - transformers.configuration_utils -   Model config BertConfig {
  "_num_labels": 2,
  "architectures": [
    "BertForQuestionAnswering"
  ],
  "attention_probs_dropout_prob": 0.1,
  "bad_words_ids": null,
  "bos_token_id": null,
  "decoder_start_token_id": null,
  "do_sample": false,
  "early_stopping": false,
  "eos_token_id": null,
  "finetuning_task": null,
  "hidden_act": "gelu",
  "hidden_dropout_prob": 0.1,
  "hidden_size": 768,
  "id2label": {
    "0": "LABEL_0",
    "1": "LABEL_1"
  },
  "initializer_range": 0.02,
  "intermediate_size": 3072,
  "is_decoder": false,
  "is_encoder_decoder": false,
  "label2id": {
    "LABEL_0": 0,
    "LABEL_1": 1
  },
  "layer_norm_eps": 1e-12,
  "length_penalty": 1.0,
  "max_length": 20,
  "max_position_embeddings": 512,
  "min_length": 0,
  "model_type": "bert",
  "no_repeat_ngram_size": 0,
  "num_attention_heads": 12,
  "num_beams": 1,
  "num_hidden_layers": 12,
  "num_return_sequences": 1,
  "output_attentions": false,
  "output_hidden_states": false,
  "output_past": true,
  "pad_token_id": 0,
  "prefix": null,
  "pruned_heads": {},
  "repetition_penalty": 1.0,
  "task_specific_params": null,
  "temperature": 1.0,
  "top_k": 50,
  "top_p": 1.0,
  "torchscript": false,
  "type_vocab_size": 2,
  "use_bfloat16": false,
  "vocab_size": 31090
}

05/06/2020 12:57:36 - INFO - transformers.tokenization_utils -   Model name 'output_finetuned_model/squad' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc, bert-base-german-dbmdz-cased, bert-base-german-dbmdz-uncased, bert-base-finnish-cased-v1, bert-base-finnish-uncased-v1, bert-base-dutch-cased). Assuming 'output_finetuned_model/squad' is a path, a model identifier, or url to a directory containing tokenizer files.
05/06/2020 12:57:36 - INFO - transformers.tokenization_utils -   Didn't find file output_finetuned_model/squad\added_tokens.json. We won't load it.
05/06/2020 12:57:36 - INFO - transformers.tokenization_utils -   loading file output_finetuned_model/squad\vocab.txt
05/06/2020 12:57:36 - INFO - transformers.tokenization_utils -   loading file None
05/06/2020 12:57:36 - INFO - transformers.tokenization_utils -   loading file output_finetuned_model/squad\special_tokens_map.json
05/06/2020 12:57:36 - INFO - transformers.tokenization_utils -   loading file output_finetuned_model/squad\tokenizer_config.json
05/06/2020 12:57:36 - INFO - transformers.modeling_utils -   loading weights file output_finetuned_model/squad\pytorch_model.bin
05/06/2020 12:57:39 - INFO - my_run_squad -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir=None, device=device(type='cuda'), do_eval=True, do_lower_case=True, do_train=True, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level=None, gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=50, max_answer_length=128, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='output_finetuned_model/squad', model_type='bert', n_best_size=20, n_gpu=1, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, output_dir='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\bioasq', overwrite_cache=False, overwrite_output_dir=False, per_gpu_eval_batch_size=64, per_gpu_train_batch_size=8, predict_file='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\test_combined\\BioASQ-task8bPhaseB-testset_combined_squad_format.json', save_steps=2000, seed=42, server_ip='', server_port='', threads=2, tokenizer_name='', train_file='D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\train_combined\\trainset_combined_squad_format.json', verbose_logging=False, version_2_with_negative=True, warmup_steps=550, weight_decay=0.0)
05/06/2020 12:57:39 - INFO - my_run_squad -   Creating features from dataset file at .
100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3243/3243 [00:12<00:00, 252.04it/s]
convert squad examples to features: 100%|███████████████████████████████████████████████████████████████████████████| 27312/27312 [02:03<00:00, 221.35it/s]
add example index and unique id: 100%|██████████████████████████████████████████████████████████████████████████| 27312/27312 [00:00<00:00, 1189080.55it/s]
05/06/2020 13:00:02 - INFO - my_run_squad -   Saving features into cached file .\cached_train_squad_384
05/06/2020 13:00:50 - INFO - my_run_squad -   ***** Running training *****
05/06/2020 13:00:50 - INFO - my_run_squad -     Num examples = 32702
05/06/2020 13:00:50 - INFO - my_run_squad -     Num Epochs = 3
05/06/2020 13:00:50 - INFO - my_run_squad -     Instantaneous batch size per GPU = 8
05/06/2020 13:00:50 - INFO - my_run_squad -     Total train batch size (w. parallel, distributed & accumulation) = 8
05/06/2020 13:00:50 - INFO - my_run_squad -     Gradient Accumulation steps = 1
05/06/2020 13:00:50 - INFO - my_run_squad -     Total optimization steps = 12264
05/06/2020 13:00:50 - INFO - my_run_squad -     Starting fine-tuning.
Epoch:   0%|                                                                                                                         | 0/3 [00:00<?, ?it/s]
Iteration:   0%|                                                                                                                  | 0/4088 [00:00<?, ?it/s]
Iteration:   0%|                                                                                                          | 1/4088 [00:00<51:05,  1.33it/s]
Iteration:   0%|                                                                                                          | 2/4088 [00:01<47:44,  1.43it/s]
Iteration:   0%|                                                                                                          | 3/4088 [00:01<40:53,  1.66it/s]
Iteration:   0%|                                                                                                          | 4/4088 [00:02<36:07,  1.88it/s]
Iteration:   0%|▏                                                                                                         | 5/4088 [00:02<32:56,  2.07it/s]
Iteration:   0%|▏                                                                                                         | 6/4088 [00:02<30:33,  2.23it/s]
Iteration:   0%|▏                                                                                                         | 7/4088 [00:03<28:53,  2.35it/s]
Iteration:   0%|▏                                                                                                         | 8/4088 [00:03<27:42,  2.45it/s]
Iteration:   0%|▏                                                                                                         | 9/4088 [00:03<26:59,  2.52it/s]
Iteration:   0%|▎                                                                                                        | 10/4088 [00:04<26:27,  2.57it/s]
Iteration:   0%|▎                                                                                                        | 11/4088 [00:04<25:57,  2.62it/s]
Iteration:   0%|▎                                                                                                        | 12/4088 [00:05<25:42,  2.64it/s]
Iteration:   0%|▎                                                                                                        | 13/4088 [00:05<25:30,  2.66it/s]
Iteration:   0%|▎                                                                                                        | 14/4088 [00:05<25:24,  2.67it/s]
Iteration:   0%|▍                                                                                                        | 15/4088 [00:06<25:21,  2.68it/s]
Iteration:   0%|▍                                                                                                        | 16/4088 [00:06<25:19,  2.68it/s]
# Out:
#   File "<ipython-input-5-1ff73e88132d>", line 5
#     05/06/2020 12:57:36 - WARNING - my_run_squad -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
#      ^
# SyntaxError: invalid token

# %%
{'exact': 41.82424916573971,
 'f1': 65.43424456598274,
 'total': 1798,
 'HasAns_exact': 41.82424916573971,
 'HasAns_f1': 65.43424456598274,
 'HasAns_total': 1798,
 'best_exact': 41.82424916573971,
 'best_exact_thresh': 0.0,
 'best_f1': 65.43424456598274,
 'best_f1_thresh': 0.0}
