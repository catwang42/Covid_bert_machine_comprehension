# %%
import argparse
import glob
import logging
import os
import random
import timeit

#this reloads the module ( required when we updated the my_run_squad  module offline)
# %load_ext autoreload
# %autoreload 2

import torch
import importlib #import reload
import torch.nn as nn
from transformers import *
from my_run_squad import main as my_main # import main as my_main

#importlib.reload(my_run_squad)

# %%
torch.cuda.empty_cache()
model_path = "output_finetuned_model/covidsquad"
base_path = os.path.abspath('')
grand_parent_path =os.path.abspath('..\..')
#print(grand_parent_path)

# fine tune with squad v2
out_dir = os.path.join(base_path,"output_finetuned_model", "covidbioasq3")
train_dir = os.path.join(base_path,"bioasq_data\\train_combined", "trainset_combined_squad_format.json")
eval_dir = os.path.join(base_path,"bioasq_data\\test_combined", "BioASQ-task8bPhaseB-testset_combined_squad_format.json")
#print(out_dir)
#print(train_dir)
#print(eval_dir)

my_main(model_path,out_dir,train_dir,eval_dir)
# Out:
# {'model_type': 'bert', 'model_name_or_path': 'output_finetuned_model/covidsquad', 'output_dir': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\output_finetuned_model\\covidbioasq3', 'data_dir': None, 'train_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\train_combined\\trainset_combined_squad_format.json', 'predict_file': 'D:\\stanford_courses\\nlu-all\\final_project\\cs224u\\dev_notebook\\finetune\\bioasq_data\\test_combined\\BioASQ-task8bPhaseB-testset_combined_squad_format.json', 'config_name': '', 'tokenizer_name': '', 'cache_dir': '', 'version_2_with_negative': True, 'null_score_diff_threshold': 0.0, 'max_seq_length': 384, 'doc_stride': 128, 'max_query_length': 64, 'do_train': True, 'do_eval': True, 'evaluate_during_training': False, 'do_lower_case': True, 'per_gpu_train_batch_size': 8, 'per_gpu_eval_batch_size': 64, 'learning_rate': 3e-05, 'gradient_accumulation_steps': 1, 'weight_decay': 0.0, '
# ...

# %%
#I took catherins pre-trained model and then I finetuned on directly on bioasq 
{'exact': 37.096774193548384,
 'f1': 60.706622318782976,
 'total': 1798,
 'HasAns_exact': 37.096774193548384,
 'HasAns_f1': 60.706622318782976,
 'HasAns_total': 1798,
 'best_exact': 37.096774193548384,
 'best_exact_thresh': 0.0,
 'best_f1': 60.706622318782976,
 'best_f1_thresh': 0.0}
# Out:
#   File "<ipython-input-3-072be6bbe69a>", line 1
#     I took catherins pre-trained model and the I finetuned on squad2 and then sci
#          ^
# SyntaxError: invalid syntax

# %%
#I took catherins pre-trained model and then I finetuned on directly on Squad2 and then bioasq 
'exact': 40.10011123470523,
 'f1': 62.83773130642504,
 'total': 1798,
 'HasAns_exact': 40.10011123470523,
 'HasAns_f1': 62.83773130642504,
 'HasAns_total': 1798,
 'best_exact': 40.10011123470523,
 'best_exact_thresh': 0.0,
 'best_f1': 62.83773130642504,
 'best_f1_thresh': 0.0}
